# %% [markdown]
# The model below uses fully connected layers to classify digits. After 50 training epoch, we achieve 99+% accuracy.

# %%
import pandas as pd
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import RMSprop, Adadelta, Adam
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split

dig = load_digits()
onehot_target = pd.get_dummies(dig.target)
x_train, x_val, y_train, y_val = train_test_split(dig.data, onehot_target, test_size=0.1, random_state=20)

model = Sequential()
model.add(Dense(128, input_dim=x_train.shape[1], activation='sigmoid'))
model.add(Dense(128, activation='sigmoid'))
model.add(Dense(10, activation='softmax'))

model.summary()

model.compile(optimizer=Adadelta(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
model.fit(x_train, y_train, epochs=50, batch_size=64)

scores = model.evaluate(x_val, y_val)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# Using TensorFlow backend.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 26,122
# Trainable params: 26,122
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1617/1617 [==============================] - 0s 198us/step - loss: 2.0561 - categorical_accuracy: 0.4552
# Epoch 2/50
# 1617/1617 [==============================] - 0s 27us/step - loss: 1.3702 - categorical_accuracy: 0.8609
# Epoch 3/50
# 1617/1617 [==============================] - 0s 27us/step - loss: 0.9022 - categorical_accuracy: 0.9116
# Epoch 4/50
# 1617/1617 [==============================] - 0s 26us/step - loss: 0.6233 - categorical_accuracy: 0.9320
# Epoch 5/50
# 1617/1617 [==============================] - 0s 27us/step - loss: 0.4556 - categorical_accuracy: 0.9462
# Epoch 6/50
# 1617/1617 [==============================] - 0s 28us/step - loss: 0.3485 - categorical_accuracy: 0.9598
# Epoch 7/50
# 1617/1617 [==============================] - 0s 28us/step - loss: 0.2787 - categorical_accuracy: 0.9660
# Epoch 8/50
# 1617/1617 [==============================] - 0s 27us/step - loss: 0.2287 - categorical_accuracy: 0.9703
# Epoch 9/50
# 1617/1617 [==============================] - 0s 26us/step - loss: 0.1898 - categorical_accuracy: 0.9777
# Epoch 10/50
# 1617/1617 [==============================] - 0s 27us/step - loss: 0.1654 - categorical_accuracy: 0.9771
# Epoch 11/50
# 1617/1617 [==============================] - 0s 27us/step - loss: 0.1383 - categorical_accuracy: 0.9827
# Epoch 12/50
# 1617/1617 [==============================] - 0s 28us/step - loss: 0.1220 - categorical_accuracy: 0.9808
# Epoch 13/50
# 1617/1617 [==============================] - 0s 28us/step - loss: 0.1091 - categorical_accuracy: 0.9839
# Epoch 14/50
# 1617/1617 [==============================] - 0s 27us/step - loss: 0.0960 - categorical_accuracy: 0.9876
# Epoch 15/50
# 1617/1617 [==============================] - 0s 28us/step - loss: 0.0848 - categorical_accuracy: 0.9889
# Epoch 16/50
# 1617/1617 [==============================] - 0s 28us/step - loss: 0.0786 - categorical_accuracy: 0.9895
# Epoch 17/50
# 1617/1617 [==============================] - 0s 27us/step - loss: 0.0688 - categorical_accuracy: 0.9913
# Epoch 18/50
# 1617/1617 [==============================] - 0s 30us/step - loss: 0.0624 - categorical_accuracy: 0.9907
# Epoch 19/50
# 1617/1617 [==============================] - 0s 28us/step - loss: 0.0559 - categorical_accuracy: 0.9932
# Epoch 20/50
# 1617/1617 [==============================] - 0s 27us/step - loss: 0.0514 - categorical_accuracy: 0.9938
# Epoch 21/50
# 1617/1617 [==============================] - 0s 28us/step - loss: 0.0470 - categorical_accuracy: 0.9944
# Epoch 22/50
# 1617/1617 [==============================] - 0s 28us/step - loss: 0.0426 - categorical_accuracy: 0.9951
# Epoch 23/50
# 1617/1617 [==============================] - 0s 27us/step - loss: 0.0391 - categorical_accuracy: 0.9957
# Epoch 24/50
# 1617/1617 [==============================] - 0s 27us/step - loss: 0.0360 - categorical_accuracy: 0.9957
# Epoch 25/50
# 1617/1617 [==============================] - 0s 29us/step - loss: 0.0331 - categorical_accuracy: 0.9969
# Epoch 26/50
# 1617/1617 [==============================] - 0s 25us/step - loss: 0.0301 - categorical_accuracy: 0.9975
# Epoch 27/50
# 1617/1617 [==============================] - 0s 27us/step - loss: 0.0274 - categorical_accuracy: 0.9988
# Epoch 28/50
# 1617/1617 [==============================] - 0s 26us/step - loss: 0.0257 - categorical_accuracy: 0.9981
# Epoch 29/50
# 1617/1617 [==============================] - 0s 25us/step - loss: 0.0249 - categorical_accuracy: 0.9988
# Epoch 30/50
# 1617/1617 [==============================] - 0s 25us/step - loss: 0.0225 - categorical_accuracy: 0.9981
# Epoch 31/50
# 1617/1617 [==============================] - 0s 26us/step - loss: 0.0208 - categorical_accuracy: 0.9981
# Epoch 32/50
# 1617/1617 [==============================] - 0s 25us/step - loss: 0.0198 - categorical_accuracy: 0.9988
# Epoch 33/50
# 1617/1617 [==============================] - 0s 26us/step - loss: 0.0181 - categorical_accuracy: 0.9988
# Epoch 34/50
# 1617/1617 [==============================] - 0s 25us/step - loss: 0.0166 - categorical_accuracy: 0.9988
# Epoch 35/50
# 1617/1617 [==============================] - 0s 25us/step - loss: 0.0158 - categorical_accuracy: 0.9988
# Epoch 36/50
# 1617/1617 [==============================] - 0s 27us/step - loss: 0.0146 - categorical_accuracy: 0.9988
# Epoch 37/50
# 1617/1617 [==============================] - 0s 25us/step - loss: 0.0136 - categorical_accuracy: 0.9988
# Epoch 38/50
# 1617/1617 [==============================] - 0s 26us/step - loss: 0.0129 - categorical_accuracy: 0.9988
# Epoch 39/50
# 1617/1617 [==============================] - 0s 25us/step - loss: 0.0120 - categorical_accuracy: 0.9988
# Epoch 40/50
# 1617/1617 [==============================] - 0s 28us/step - loss: 0.0113 - categorical_accuracy: 0.9988
# Epoch 41/50
# 1617/1617 [==============================] - 0s 25us/step - loss: 0.0105 - categorical_accuracy: 0.9988
# Epoch 42/50
# 1617/1617 [==============================] - 0s 25us/step - loss: 0.0099 - categorical_accuracy: 0.9988
# Epoch 43/50
# 1617/1617 [==============================] - 0s 25us/step - loss: 0.0091 - categorical_accuracy: 0.9994
# Epoch 44/50
# 1617/1617 [==============================] - 0s 27us/step - loss: 0.0088 - categorical_accuracy: 0.9994
# Epoch 45/50
# 1617/1617 [==============================] - 0s 25us/step - loss: 0.0083 - categorical_accuracy: 0.9994
# Epoch 46/50
# 1617/1617 [==============================] - 0s 27us/step - loss: 0.0075 - categorical_accuracy: 1.0000
# Epoch 47/50
# 1617/1617 [==============================] - 0s 27us/step - loss: 0.0073 - categorical_accuracy: 1.0000
# Epoch 48/50
# 1617/1617 [==============================] - 0s 26us/step - loss: 0.0070 - categorical_accuracy: 0.9994
# Epoch 49/50
# 1617/1617 [==============================] - 0s 26us/step - loss: 0.0064 - categorical_accuracy: 1.0000
# Epoch 50/50
# 1617/1617 [==============================] - 0s 25us/step - loss: 0.0062 - categorical_accuracy: 0.9994
# 180/180 [==============================] - 0s 132us/step
#
# categorical_accuracy: 98.89%
